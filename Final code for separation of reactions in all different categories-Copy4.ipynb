# %%
import numpy as np
import pandas as pd
import cobra.test
import os

from os.path import join

from time import time


from cobra.flux_analysis import (
    single_gene_deletion, single_reaction_deletion, double_gene_deletion,
    double_reaction_deletion)

a = cobra.io.read_sbml_model("iEC1344_C.xml")

# %%
csvFile = pd.read_csv('biomass_per_flux_for_reaction_ALAALAD.csv') #this is flat and then decreasing i.e. saturating
i=0
l= list()

while i < 201:
    inf= csvFile.iloc[i,  2]
    flt= float(csvFile.iloc[i,  2])
    
    if csvFile.iloc[i,  2] == flt:
        l.append(csvFile.iloc[i,  2])
    i= i+1

csvFile2= pd.DataFrame (l, columns = ['Biomass'])
csvFile2

my_series = csvFile2['Biomass'].squeeze()
type(my_series)

my_series

if my_series.is_monotonic_decreasing == False and my_series.is_monotonic == False:
    print("This reaction is both increasting and decreasing.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-c256ffe8a0d4> in <module>
# ----> 1 csvFile = pd.read_csv('biomass_per_flux_for_reaction_ALAALAD.csv') #this is flat and then decreasing i.e. saturating
#       2 i=0
#       3 l= list()
#       4
#       5 while i < 201:
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'biomass_per_flux_for_reaction_ALAALAD.csv'

# %%
int_reactions= list()
i= -1
r = a.reactions[0]
r_id = r.id
zero= list()
one= list()

for r in a.reactions:
    i= i+1
    r = a.reactions[i]
    r_id = r.id

    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_anaerobic.csv'.format(r_id))
    v= len(csvFile["Biomass"])-csvFile["Biomass"].isna().sum()
    
    if v == 1:
        one.append(r_id)
    elif v == 0:
        zero.append(r_id)

print(one)
print(zero)

D= pd.DataFrame (one, columns = ['1 feasible value'])
D
# Out:
# ['EX_cm_e', 'EX_cobalt2_e', 'EX_colipa_e', 'EX_colipap_e', 'EX_crn_e', 'EX_crn__D_e', 'EX_cu_e', 'DM_4crsol_c', 'EX_cu2_e', 'DM_5drib_c', 'EX_cyan_e', 'DM_aacald_c', 'DM_amob_c', 'DM_mththf_c', 'DM_oxam_c', 'EX_glyb_e', 'EX_gthox_e', 'BIOMASS_Ec_iJO1366_WT_53p95M', 'BIOMASS_Ec_iJO1366_core_53p95M', 'EX_14glucan_e', 'EX_15dap_e', 'EX_h2o2_e', 'EX_h2s_e', 'EX_hacolipa_e', 'EX_halipa_e', 'EX_hdca_e', 'EX_34dhpac_e', 'EX_hdcea_e', 'EX_3hcinnm_e', 'EX_3hpp_e', 'EX_3hpppn_e', 'EX_hg2_e', 'EX_his__L_e', 'EX_hom__L_e', 'EX_hxa_e', 'EX_4hoxpacd_e', 'EX_5mtr_e', 'EX_cys__D_e', 'EX_ile__L_e', 'EX_acgal_e', 'EX_inost_e', 'EX_isetac_e', 'EX_k_e', 'EX_kdo2lipid4_e', 'EX_acolipa_e', 'EX_acser_e', 'EX_adocbl_e', 'EX_leu__L_e', 'EX_lipa_e', 'EX_lipa_cold_e', 'EX_ag_e', 'EX_lipoate_e', 'EX_ala_B_e', 'EX_ddca_e', 'EX_malthx_e', 'EX_maltpt_e', 'EX_malttr_e', 'EX_maltttr_e', 'EX_arbt_e', 'EX_meoh_e', 'EX_met__D_e', 'EX_aso3_e', 'EX_met__L_e', 'EX_metsox_R__L_e', 'EX_metsox_S__L_e', 'EX_mg2_e', 'EX_mincyc_e', 'EX_btn_e', 'EX_mmet_e', 'EX_mn2_e', 'EX_butso3_e', 'EX_ca2_e', 'EX_cbi_e', 'EX_mobd_e', 'EX_mso3_e', 'EX_n2o_e', 'EX_na1_e', 'EX_nac_e', 'EX_cbl1_e', 'EX_cd2_e', 'EX_chol_e', 'EX_cit_e', 'EX_cl_e', 'EX_ni2_e', 'EX_nmn_e', 'EX_dms_e', 'EX_novbcn_e', 'EX_dopa_e', 'EX_o16a4colipa_e', 'EX_doxrbcn_e', 'EX_o2s_e', 'EX_ocdca_e', 'EX_ocdcea_e', 'EX_xtsn_e', 'EX_pacald_e', 'EX_zn2_e', '12DGR120tipp', '12DGR140tipp', '12DGR141tipp', '12DGR160tipp', 'EX_peamn_e', 'EX_phe__L_e', 'EX_pheme_e', 'EX_pi_e', 'EX_pnto__R_e', 'EX_ppa_e', 'EX_ppal_e', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', 'EX_pppn_e', '14GLUCANtexi', 'EX_eca4colipa_e', '23CAMPtex', '23CCMPtex', 'EX_pydam_e', '23CGMPtex', '23CUMPtex', '23DAPPAt2pp', '23DAPPAtex', '23PDE2pp', '23PDE4pp', 'EX_pydx_e', 'EX_pydxn_e', 'EX_quin_e', 'EX_rfamp_e', '23PDE7pp', '23PDE9pp', 'EX_enlipa_e', 'EX_sel_e', '26DAHtex', '2AGPA120tipp', '2AGPA140tipp', '2AGPA141tipp', 'EX_skm_e', '2AGPA160tipp', 'EX_slnt_e', '2AGPA161tipp', '2AGPA180tipp', '2AGPA181tipp', 'EX_so2_e', 'EX_so3_e', '2AGPE120tipp', 'EX_ethso3_e', '2AGPE140tipp', '2AGPE141tipp', 'EX_so4_e', 'EX_spmd_e', 'EX_sulfac_e', 'EX_taur_e', 'EX_tcynt_e', 'EX_thm_e', '2AGPE160tipp', '2AGPE161tipp', '2AGPE180tipp', '2AGPE181tipp', 'EX_thym_e', '2AGPEAT120', '2AGPEAT140', 'EX_tma_e', '2AGPEAT141', '2AGPEAT160', '2AGPEAT161', '2AGPEAT180', 'EX_tsul_e', 'EX_ttdca_e', 'EX_ttrcyc_e', '2AGPEAT181', '2AGPG120tipp', '2AGPG140tipp', '2AGPG141tipp', '2AGPG160tipp', '2AGPG161tipp', 'EX_tungs_e', 'EX_tym_e', '2AGPG180tipp', '2AGPG181tipp', '2AGPGAT120', 'EX_tyr__L_e', '2AGPGAT140', '2AGPGAT141', '2AGPGAT160', 'EX_fe3dhbzs_e', '2AGPGAT161', '2AGPGAT180', '2AGPGAT181', 'EX_ura_e', 'EX_urea_e', '34dhpactex', '3GMPtex', '3HAD100', '3AMACHYD', '3AMPtex', '3CMPtex', '3HAD120', '3HAD121', '3HAD140', '3HAD141', '3HAD160', '3HAD161', 'EX_fuc__L_e', '3HAD180', '3HAD181', '3HAD40', '3HAD60', '3HAD80', '3HCINNMH', 'AACTOOR', 'AADDGT', 'AAMYLpp', '3HPPPNH', '3HPPtex', '3HPPtpp', '3KGK', 'AB6PGH', 'ABTA', 'ABUTD', '3NTD2pp', '3NTD4pp', '3NTD7pp', 'ABUTtex', 'EX_fusa_e', '3NTD9pp', '3OAR100', '3OAR120', '3OAR121', '3OAR140', '3OAR141', '3OAR160', '3OAR161', '3OAR180', '3OAR181', '3OAR40', 'ACACt2pp', 'ACACtex', '3OAR60', '3OAR80', '3OAS100', '3OAS120', '3OAS121', '3OAS140', '3OAS141', '3OAS160', 'ACANTHAT', 'ACBIPGT', '3OAS161', '3OAS180', '3OAS181', '3OAS60', 'ACGAL1PPpp', 'ACGAL1Ptex', 'ACGALtex', 'ACGAM1PPpp', 'ACGAM1Ptex', 'ACGAMK', 'ACGAMT', '3OAS80', '3PEPTabcpp', '3PEPTtex', '3UMPtex', '42A12BOOXpp', 'ACGAptspp', 'ACGAtex', '4HOXPACDtex', '4HTHRS', '4PCP', 'ACGK', 'ACGS', 'ACHBS', '4PCPpp', '4PEPTabcpp', 'ACM6PH', 'ACMAMUT', '4PEPTtex', '5DGLCNR', '5DGLCNt2rpp', 'ACMANAptspp', 'ACMANAtex', 'ACMUMptspp', 'ACMUMtex', 'ACNAMt2pp', '5DGLCNtex', '5DOAN', '5MTRtex', '5MTRtpp', 'A5PISO', 'ACNAMtex', 'ACNML', 'ACOAD1f', 'ACOAD2f', 'ACOAD3f', 'ACOAD4f', 'ACOAD5f', 'ACODA', 'ACOAD6f', 'ACOAD7f', 'ACOAD8f', 'ACONIs', 'ACONMT', 'ACONTa', 'ACONTb', 'ACOTA', 'AGPAT181', 'AGPR', 'AGt3', 'AH ...
# []
#      1 feasible value
# 0             EX_cm_e
# 1        EX_cobalt2_e
# 2         EX_colipa_e
# 3        EX_colipap_e
# 4            EX_crn_e
# ...               ...
# 1693             SUCP
# 1694           TARTDC
# 1695          LTARTDH
# 1696           UAG4Ei
# 1697          UGCIAMH
#
# [1698 rows x 1 columns]

# %%
i= 0
diff_saturated= list()
diff_indecr= list()
flat= list()
r = a.reactions[0]


for r in a.reactions:
    
    l= list()
    n=0
    n2=0
    count=0
    r = a.reactions[i]
    r_id = r.id
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_anaerobic.csv'.format(r_id))

    while n < 201:
        inf= csvFile.iloc[n,  2]
        flt= float(csvFile.iloc[n,  2])
    
        if csvFile.iloc[n,  2] == flt:
            l.append(csvFile.iloc[n,  2])
        n= n+1

    d= pd.DataFrame (l, columns = ['Biomass'])


    if len(d)> 1:
        
        while n2 < len(d):

            if d.iloc[n2,  0] > max(d["Biomass"])-0.02 and d.iloc[n2,  0] < max(d["Biomass"])+0.02:
                count= count+1
    
            n2= n2+1
        
        if count> 0.8*len(d) and count< 0.95*len(d):
            diff_saturated.append(r_id)

        elif count> 0.95*len(d):
            flat.append(r_id)
        
        else:
            diff_indecr.append(r_id)

    
    i= i+1

flat
diff_indecr
diff_saturated
# Out:
# ['ACOLIPAabctex',
#  'ALAALAD',
#  'ALAabcpp',
#  'ALDD2x',
#  'ASPabcpp',
#  'ATPM',
#  'CHLabcpp',
#  'CLIPAabctex',
#  'CBPS',
#  'CD2abcpp',
#  'COBALT2abcpp',
#  'COLIPAabctex',
#  'CRNDabcpp',
#  'CRNabcpp',
#  'CTBTabcpp',
#  'CU1Opp',
#  'CU1abcpp',
#  'CYSabc2pp',
#  'ARBabcpp',
#  'ECA4COLIPAabctex',
#  'ENLIPAabctex',
#  'ARGabcpp',
#  'FE2abcpp',
#  'ASNabcpp',
#  'G3PD5',
#  'G3PD6',
#  'G3PD7',
#  'ASPO3',
#  'ASPO4',
#  'ASPO5',
#  'GLCabcpp',
#  'ASPT',
#  'GALabcpp',
#  'GLUabcpp',
#  'GLYBabcpp',
#  'GLYC3Pabcpp',
#  'IDOND2',
#  'HG2abcpp',
#  'ILEabcpp',
#  'HISabcpp',
#  'HPYRRy',
#  'Kabcpp',
#  'LDH_D2',
#  'LEUabcpp',
#  'LIPAabctex',
#  'LYSabcpp',
#  'MDH2',
#  'MDH3',
#  'MG2uabcpp',
#  'NADH10',
#  'NADH5',
#  'NADH9',
#  'NADPHQR2',
#  'NADPHQR3',
#  'NADPHQR4',
#  'NADTRHD',
#  'NI2abcpp',
#  'NI2uabcpp',
#  'NTP1',
#  'NTP10',
#  'NTP3',
#  'NTP5',
#  'NTPP1',
#  'NTPP2',
#  'NTPP3',
#  'NTPP4',
#  'NTPP5',
#  'NTPP6',
#  'NTPP7',
#  'NTPP8',
#  'ORNabcpp',
#  'PDH',
#  'PROabcpp',
#  'PIuabcpp',
#  'PTRCabcpp',
#  'SPODM',
#  'SULabcpp',
#  'THRA2',
#  'THRabcpp',
#  'VALabcpp',
#  'XYLabcpp',
#  'ZN2abcpp',
#  'ZNabcpp',
#  'POX',
#  'PPA',
#  'PPA2',
#  'PPPGO',
#  'DARBabcpp',
#  'DURAD',
#  'PYRDC']

# %%
i= 0
r_id= diff_saturated[i]
diff_saturatedFINAL= list()
Ushaped_reactions= list()

for r_id in diff_saturated:

    l= list()
    n=0
    n2=0
    r_id = diff_saturated[i]
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_anaerobic.csv'.format(r_id))

    while n < 201:
        inf= csvFile.iloc[n,  2]
        flt= float(csvFile.iloc[n,  2])
    
        if csvFile.iloc[n,  2] == flt:
            l.append(csvFile.iloc[n,  2])
        n= n+1

    d= pd.DataFrame (l, columns = ['Biomass'])
    
    if d.iloc[0,0] > d.iloc[1,0]-0.02 and d.iloc[0,0] < d.iloc[1,0]+0.02 or\
       d.iloc[1,0] > d.iloc[0,0]-0.02 and d.iloc[1,0] < d.iloc[0,0]+0.02 or\
       d.iloc[len(d)-2,0] > d.iloc[len(d)-1,0]-0.02 and d.iloc[len(d)-2,0] < d.iloc[len(d)-1,0]+0.02 or\
       d.iloc[len(d)-1,0] > d.iloc[len(d)-2,0]-0.02 and d.iloc[len(d)-1,0] < d.iloc[len(d)-2, 0]+0.02:
        diff_saturatedFINAL.append(r_id)
    
    else:
        Ushaped_reactions.append(r_id)
    
    i= i+1

diff_saturatedFINAL
Ushaped_reactions
# Out:
# ['CU1Opp',
#  'CU1abcpp',
#  'Kabcpp',
#  'NI2uabcpp',
#  'PIuabcpp',
#  'SULabcpp',
#  'ZNabcpp',
#  'PPA',
#  'PPPGO']

# %%
i2= 0
r_id = diff_indecr[0]
mon_incr= list()
mon_decr= list()
one_feasible_value= list()

for r_id in diff_indecr:                    #this code finds reactions that are either stable or constantly decrease
    
    i=0
    r_id = diff_indecr[i2]
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_anaerobic.csv'.format(r_id))
    l= list()

    while i < 201:
        inf= csvFile.iloc[i,  2]
        flt= float(csvFile.iloc[i,  2])
    
        if csvFile.iloc[i,  2] == flt:
            l.append(csvFile.iloc[i,  2])
        i= i+1

    csvFile2= pd.DataFrame (l, columns = ['Biomass'])
    csvFile2.Biomass = csvFile2.Biomass.round(2)

    my_series = csvFile2['Biomass'].squeeze()
    type(my_series)

    if len(csvFile2['Biomass'])>1:
        
        if my_series.is_monotonic_decreasing ==True:
            mon_decr.append(r_id)
        elif my_series.is_monotonic ==True:
            mon_incr.append(r_id)

    
    i2= i2 + 1

mon_decr
# Out:
# ['EX_csn_e',
#  'EX_glcn_e',
#  'EX_glcur_e',
#  'EX_glcur1p_e',
#  'EX_glu__L_e',
#  'EX_gly_e',
#  'EX_glyald_e',
#  'EX_glyc_e',
#  'EX_glyc__R_e',
#  'EX_glyc2p_e',
#  'EX_glyc3p_e',
#  'EX_gmp_e',
#  'EX_gsn_e',
#  'EX_12ppd__R_e',
#  'EX_2ddglcn_e',
#  'EX_3amp_e',
#  'EX_3gmp_e',
#  'EX_3ump_e',
#  'EX_5dglcn_e',
#  'EX_LalaDglu_e',
#  'EX_cytd_e',
#  'EX_LalaLglu_e',
#  'EX_idon__L_e',
#  'EX_dad_2_e',
#  'EX_imp_e',
#  'EX_acald_e',
#  'EX_damp_e',
#  'EX_ins_e',
#  'EX_lac__D_e',
#  'EX_lcts_e',
#  'EX_adn_e',
#  'EX_dcyt_e',
#  'EX_akg_e',
#  'EX_mal__D_e',
#  'EX_ala__L_e',
#  'EX_mal__L_e',
#  'EX_dgmp_e',
#  'EX_man6p_e',
#  'EX_amp_e',
#  'EX_arg__L_e',
#  'EX_dgsn_e',
#  'EX_asp__L_e',
#  'EX_dha_e',
#  'EX_dimp_e',
#  'EX_din_e',
#  'EX_chtbs_e',
#  'EX_dtmp_e',
#  'EX_orn_e',
#  'EX_dump_e',
#  'EX_duri_e',
#  'EX_pyr_e',
#  'EX_rmn_e',
#  'EX_ser__D_e',
#  'EX_ser__L_e',
#  'EX_etha_e',
#  'EX_f6p_e',
#  'EX_thr__L_e',
#  'EX_thymd_e',
#  'EX_fe2_e',
#  'EX_fe3_e',
#  'EX_tre_e',
#  'EX_trp__L_e',
#  'EX_ump_e',
#  'EX_uri_e',
#  '2MAHMP',
#  'EX_fruur_e',
#  'AACPS5',
#  'AACPS6',
#  'AACPS7',
#  'AACPS8',
#  'AACPS9',
#  'EX_fum_e',
#  'EX_g1p_e',
#  'EX_g3pc_e',
#  'EX_g3pe_e',
#  'EX_g3pg_e',
#  'EX_g3pi_e',
#  'EX_g3ps_e',
#  'EX_g6p_e',
#  'AACPS1',
#  'AACPS2',
#  'AACPS3',
#  'AACPS4',
#  'EX_gal_bD_e',
#  'EX_gal1p_e',
#  'EX_galctn__D_e',
#  'ACPPAT120',
#  'ACPPAT140',
#  'ACPPAT141',
#  'ACPPAT180',
#  'EX_galctn__L_e',
#  'ACPPAT181',
#  'EX_galur_e',
#  'ADNCYC',
#  'ALDD2y',
#  'ALR2',
#  'ALR4x',
#  'AP4AH',
#  'AP4AS',
#  'ASPt2_2pp',
#  'ASPt2_3pp',
#  'CDAPPA181',
#  'APH120',
#  'APH140',
#  'APH141',
#  'APH160',
#  'APH161',
#  'CMtex',
#  'CMtpp',
#  'APH180',
#  'CD2tpp',
#  'CDAPPA120',
#  'APH181',
#  'CDAPPA140',
#  'CDAPPA141',
#  'CDAPPA160',
#  'CDAPPA161',
#  'CDAPPA180',
#  'CPGNUtex',
#  'CPGNUtpp',
#  'CPGNabcpp',
#  'CPGNexs',
#  'CPGNtonex',
#  'DASYN120',
#  'ARBTNabcpp',
#  'DASYN140',
#  'DASYN141',
#  'CU2abcpp',
#  'ARBTNexs',
#  'DASYN180',
#  'DASYN181',
#  'ARBTNtex',
#  'ARBTNtonex',
#  'ARBTNtpp',
#  'CYSabcpp',
#  'CYTBD2pp',
#  'CYTBDpp',
#  'DHBS',
#  'CYTK1',
#  'CYTK2',
#  'DHBSH',
#  'ARBt3ipp',
#  'DOXRBCNtex',
#  'DOXRBCNtpp',
#  'DRPA',
#  'ARGORNt7pp',
#  'EDA',
#  'EDD',
#  'DURADx',
#  'DURIPP',
#  'DUTPDP',
#  'ARGt3pp',
#  'FA100ACPHi',
#  'FA80ACPHi',
#  'FACOAE60',
#  'FBA3',
#  'FEOXAMtonex',
#  'FE2t2pp',
#  'FE2t3pp',
#  'FE3HOXUtex',
#  'FE3HOXUtpp',
#  'FE3HOXabcpp',
#  'FE3HOXexs',
#  'FE3HOXtonex',
#  'FRD2',
#  'FRD3',
#  'FE3abcpp',
#  'FE3tex',
#  'FECRMUtex',
#  'FECRMUtpp',
#  'FECRMabcpp',
#  'FECRMexs',
#  'FECRMtonex',
#  'FTHFD',
#  'FEENTERabcpp',
#  'FEENTERexs',
#  'FEENTERtex',
#  'FUMt2_3pp',
#  'FEENTERtonex',
#  'FEENTERtpp',
#  'FUSAtex',
#  'FEOXAMUtex',
#  'FUSAtpp',
#  'FEOXAMUtpp',
#  'FEOXAMabcpp',
#  'FEOXAMexs',
#  'G3PD2',
#  'G3PT',
#  'G5SD',
#  'G6PDA',
#  'G6PDH2r',
#  'GALUi',
#  'GAPD',
#  'GLU5K',
#  'GLYAT',
#  'GUAt2pp',
#  'HYPOE',
#  'HEX4',
#  'GLYOX',
#  'Kt3pp',
#  'LALDO3',
#  'LCARR',
#  'LCARS',
#  'LCTSt3ipp',
#  'LCTStpp',
#  'LGTHL',
#  'LSERDHr',
#  'LYSt3pp',
#  'MCITD',
#  'MCITL2',
#  'MCITS',
#  'MALt2_3pp',
#  'MALt3pp',
#  'MAN1PT2',
#  'MINCYCtex',
#  'MINCYCtpp',
#  'MELIBt2pp',
#  'MELIBt3ipp',
#  'MMCD',
#  'MN2t3pp',
#  'MG2tpp',
#  'MGSA',
#  'NADDP',
#  'GRXR',
#  'MTHFC',
#  'MTHFD',
#  'NADPPPS',
#  'NAt3_1p5pp',
#  'NAt3_2pp',
#  'GSPMDA',
#  'GSPMDS',
#  'NDPK3',
#  'NOVBCNtex',
#  'NOVBCNtpp',
#  'NDPK7',
#  'NTD1',
#  'NTD10',
#  'GTHOr',
#  'GTHPi',
#  'NTD4',
#  'NTD5',
#  'NTD6',
#  'GTHRDabc2pp',
#  'NO3R2bpp',
#  'GTHRDabcpp',
#  'GTPDPK',
#  'P5CD',
#  'GUACYC',
#  'PGCD',
#  'PGL',
#  'PDE1',
#  'PDE4',
#  'PGM',
#  'PDXPP',
#  'PROD2',
#  'PSERT',
#  'PSP_L',
#  'RBK',
#  'RFAMPtex',
#  'RFAMPtpp',
#  'PUNP2',
#  'PUNP4',
#  'PYAM5PO',
#  'PYDAMK',
#  'PYDXK',
#  'PYDXNK',
#  'PYDXPP',
#  'SPMDabcpp',
#  'SPMDt3pp',
#  'SUCCt2_3pp',
#  'SUCCtex',
#  'SERASr',
#  'TDP',
#  'THIORDXi',
#  'THRt2pp',
#  'TMDK1',
#  'TPI',
#  'TRDR',
#  'TRE6PP',
#  'TRE6PS',
#  'TREH',
#  'TRPAS2',
#  'TTRCYCtex',
#  'TTRCYCtpp',
#  'XANt2pp',
#  'XPPT',
#  'MME',
#  'PPGPPDP',
#  'PPM2',
#  'DKMPPD',
#  'FLDR']

# %%
mon_incr
# Out:
# ['EX_cpgn_e',
#  'EX_glyclt_e',
#  'EX_h2_e',
#  'EX_26dap__M_e',
#  'EX_4abut_e',
#  'EX_indole_e',
#  'EX_lac__L_e',
#  'EX_dca_e',
#  'EX_arbtn_fe3_e',
#  'EX_but_e',
#  'EX_octa_e',
#  'EX_orot_e',
#  '12PPDRtex',
#  '12PPDRtpp',
#  '12PPDStex',
#  '12PPDStpp',
#  'EX_pro__L_e',
#  'EX_progly_e',
#  'EX_ptrc_e',
#  'EX_succ_e',
#  'EX_fald_e',
#  'EX_ttdcea_e',
#  '2DGULRGx',
#  'EX_fe3hox_e',
#  'EX_fecrm_e',
#  'EX_feenter_e',
#  'EX_feoxam_e',
#  'ACACCT',
#  'ACALDtex',
#  'ACALDtpp',
#  'ACOATA',
#  'ALAALAabcpp',
#  'ADK4',
#  'ALAtex',
#  'ALDD3y',
#  'ASPtex',
#  'ATHRDHr',
#  'BALAt2pp',
#  'CHLt2pp',
#  'BETALDHy',
#  'BSORx',
#  'BUTCT',
#  'CMPN',
#  'CBMKr',
#  'CPGNR1',
#  'ARBTNR1',
#  'DALAt2pp',
#  'CTBTt2rpp',
#  'CUt3',
#  'DCTPD',
#  'CYTBO3_4pp',
#  'CYTD',
#  'CYTDH',
#  'DHAtex',
#  'DHAtpp',
#  'D_LACt2pp',
#  'D_LACtex',
#  'DHORD5',
#  'DMSOR1',
#  'DMSOR1pp',
#  'DMSOR2',
#  'DMSOR2pp',
#  'DOGULNR',
#  'ARGDC',
#  'EAR60x',
#  'EAR80x',
#  'DSERDHr',
#  'ENO',
#  'EAR100x',
#  'EAR120x',
#  'ENTERES',
#  'ENTERES2',
#  'EAR121x',
#  'EAR140x',
#  'EAR141x',
#  'EAR160x',
#  'EAR161x',
#  'EAR180x',
#  'EAR181x',
#  'EAR40x',
#  'FE2tex',
#  'FLVRx',
#  'FE3HOXR1',
#  'FMNRx',
#  'FECRMR1',
#  'ASNt2rpp',
#  'FRUpts2pp',
#  'FEENTERR1',
#  'FUMt2_2pp',
#  'FEOXAMR1',
#  'G2PPpp',
#  'G5SADs',
#  'ASPO6',
#  'GLCptspp',
#  'GLNabcpp',
#  'GALt2pp',
#  'GARFT',
#  'GLUNpp',
#  'GLYBt2pp',
#  'GLYCL',
#  'GUAtpp',
#  'GLYC3Pt6pp',
#  'IDOND',
#  'HEXt2rpp',
#  'HG2t3pp',
#  'ILEt2rpp',
#  'IMPD',
#  'HISt2rpp',
#  'HXAND',
#  'LACZ',
#  'LEUt2rpp',
#  'LIPOCT',
#  'MALtex',
#  'MLTP1',
#  'MLTP2',
#  'MLTP3',
#  'MG2t3_2pp',
#  'MOX',
#  'NADS1',
#  'NODOx',
#  'NMNN',
#  'NNATr',
#  'OMMBLHX',
#  'OMPHHX',
#  'OPHHX',
#  'P5CR',
#  'PA120abcpp',
#  'PA140abcpp',
#  'PA141abcpp',
#  'PA160abcpp',
#  'PA161abcpp',
#  'PA180abcpp',
#  'PA181abcpp',
#  'PAPA120',
#  'GUAD',
#  'PAPA140',
#  'PAPA141',
#  'PAPA160',
#  'PAPA161',
#  'PAPA180',
#  'PAPA181',
#  'PGK',
#  'PAPSR',
#  'PAPSR2',
#  'PGMT',
#  'PIt2rpp',
#  'PYRt2rpp',
#  'PYRtex',
#  'RBK_L1',
#  'PTRCORNt7pp',
#  'RNDR3',
#  'RNDR3b',
#  'RNDR4',
#  'RNDR4b',
#  'RNTR3c2',
#  'RPI',
#  'SSALy',
#  'SUCDi',
#  'SUCFUMtpp',
#  'SUCTARTtpp',
#  'TALA',
#  'TARTD',
#  'SO4t2pp',
#  'TMAOR1',
#  'TMAOR1pp',
#  'TMAOR2',
#  'TMAOR2pp',
#  'TREptspp',
#  'TRPS3',
#  'UM3PL',
#  'PMANM',
#  'VALtex',
#  'XANtpp',
#  'VALt2rpp',
#  'MECDPDH2',
#  'XYLt2pp',
#  'RNTR3c',
#  'RNTR4c',
#  '2DGLCNRx']

# %%
i2=0
mon_decr_and_stable= list()
mon_decr_only= list()

while i2< len(mon_decr):  #this code separates reactions that may have flat points from reactions that always decrease
    
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_anaerobic.csv'.format(mon_decr[i2]))
    i=0
    l= list()
    
    while i < 201:
        inf= csvFile.iloc[i,  2]
        flt= float(csvFile.iloc[i,  2])
    
        if csvFile.iloc[i,  2] == flt:
            l.append(csvFile.iloc[i,  2])
        i= i+1

    csvFile2= pd.DataFrame (l, columns = ['Biomass'])
    csvFile2.Biomass = csvFile2.Biomass.round(2)

    boolean = csvFile2["Biomass"].duplicated().any()
    
    if boolean == True:
        mon_decr_and_stable.append(mon_decr[i2])
    
    if boolean == False:
        mon_decr_only.append(mon_decr[i2])
    
    i2= i2+1

mon_decr_and_stable
# Out:
# ['EX_csn_e',
#  'EX_LalaDglu_e',
#  'EX_LalaLglu_e',
#  'EX_lcts_e',
#  'EX_ala__L_e',
#  'EX_man6p_e',
#  'EX_chtbs_e',
#  'EX_f6p_e',
#  'EX_tre_e',
#  'EX_trp__L_e',
#  'EX_g1p_e',
#  'EX_g6p_e',
#  'EX_gal_bD_e',
#  'EX_gal1p_e',
#  'ALDD2y',
#  'ASPt2_2pp',
#  'ASPt2_3pp',
#  'CMtpp',
#  'CYTBD2pp',
#  'CYTBDpp',
#  'ARBt3ipp',
#  'DOXRBCNtpp',
#  'FBA3',
#  'FE2t2pp',
#  'FUMt2_3pp',
#  'FUSAtpp',
#  'GUAt2pp',
#  'LCTSt3ipp',
#  'MALt2_3pp',
#  'MINCYCtpp',
#  'MG2tpp',
#  'NAt3_1p5pp',
#  'NAt3_2pp',
#  'NOVBCNtpp',
#  'GTHPi',
#  'NO3R2bpp',
#  'RFAMPtpp',
#  'SUCCt2_3pp',
#  'THIORDXi',
#  'TTRCYCtpp',
#  'XANt2pp',
#  'DKMPPD']

# %%
i2=0
mon_incr_and_stable= list()
mon_incr_only= list()

while i2< len(mon_incr):  #this code separates reactions that may have flat points from reactions that always increase
    
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_anaerobic.csv'.format(mon_incr[i2]))
    i=0
    l= list()
    
    while i < 201:
        inf= csvFile.iloc[i,  2]
        flt= float(csvFile.iloc[i,  2])
    
        if csvFile.iloc[i,  2] == flt:
            l.append(csvFile.iloc[i,  2])
        i= i+1

    csvFile2= pd.DataFrame (l, columns = ['Biomass'])
    csvFile2.Biomass = csvFile2.Biomass.round(2)

    boolean = csvFile2["Biomass"].duplicated().any()
    
    if boolean == True:
        mon_incr_and_stable.append(mon_incr[i2])
    
    if boolean == False:
        mon_incr_only.append(mon_incr[i2])
    
    i2= i2+1

mon_incr_and_stable
# Out:
# ['FRUpts2pp', 'TALA']

# %%
d.iloc[len(d)-1,0]
# Out:
# 0.0196423643844744

# %%
set1= set(diff_indecr)
set2= set(mon_decr)
set3= set(mon_incr)
inANDdecr= list(set1-set2-set3)
inANDdecr
# Out:
# ['TMPK',
#  'EX_for_e',
#  'CO2tex',
#  'ZN2tpp',
#  'RNTR2c2',
#  'NDPK4',
#  'TRE6PH',
#  'MN2tpp',
#  'HCO3E',
#  'EX_tmao_e',
#  'EX_no3_e',
#  'MALS',
#  'EX_no2_e',
#  'DTMPK',
#  'EX_val__L_e',
#  'EX_23ccmp_e',
#  'DURIK1',
#  'GLCt2pp',
#  'EX_no_e',
#  'DGK1',
#  'FUM',
#  'EX_man_e',
#  'EX_glc__D_e',
#  'NH4tex',
#  'EX_etoh_e',
#  'CD2t3pp',
#  'EX_uacgam_e',
#  'EX_23camp_e',
#  'NADK',
#  'ALAALAr',
#  'SFGTHi',
#  'GDPTPDP',
#  'EX_thrp_e',
#  'SUCASPtpp',
#  'GLUDy',
#  'DASYN160',
#  'EX_LalaDgluMdapDala_e',
#  'FLDR2',
#  'EX_arab__L_e',
#  'EX_xyl__D_e',
#  'FBP',
#  'EX_pser__L_e',
#  'NTRIR2x',
#  'GK1',
#  'EX_mnl_e',
#  'MACPD',
#  'EX_h_e',
#  'NTD2',
#  'H2Otex',
#  'ZN2t3pp',
#  'SUCMALtpp',
#  'SUCCt3pp',
#  'PPC',
#  'EX_udpacgal_e',
#  'EX_melib_e',
#  'NO3R1bpp',
#  'EX_acnam_e',
#  'EX_anhgm_e',
#  'EX_23dappa_e',
#  'MALt2_2pp',
#  'GDPDPK',
#  'NADH17pp',
#  'ETOHtex',
#  'EX_all__D_e',
#  'ETOHtrpp',
#  'ALCD2x',
#  'CAT',
#  'NDPK5',
#  'EX_nh4_e',
#  'PUNP3',
#  'EX_23cgmp_e',
#  'ARBt2rpp',
#  'ASPTA',
#  'RNTR4c2',
#  'ACCOAC',
#  'AKGDH',
#  'EX_galt_e',
#  'EX_ac_e',
#  'EX_ascb__L_e',
#  'EX_ala__D_e',
#  'FORtppi',
#  'GLYCTO4',
#  'EX_tartr__L_e',
#  'EX_acgam_e',
#  'EX_co2_e',
#  'EX_glcr_e',
#  'EX_gal_e',
#  'LDH_D',
#  'EX_udpg_e',
#  'EX_cynt_e',
#  'EX_acac_e',
#  'FADRx',
#  'Htex',
#  'MCOATA',
#  'FBA',
#  'NDPK8',
#  'H2SO',
#  'PTRCt2pp',
#  'PPS',
#  'NH4tpp',
#  'FE2tpp',
#  'EX_fru_e',
#  'GLYCDx',
#  'EX_lyx__L_e',
#  'CU2tpp',
#  'CITL',
#  'EX_acmum_e',
#  'NTD11',
#  'EX_alltn_e',
#  'FDH5pp',
#  'F6PA',
#  'SUCCt2_2pp',
#  'NI2tpp',
#  'GDPMNH',
#  'PUNP5',
#  'EX_fe3dcit_e',
#  'RNTR1c2',
#  'XYLI2',
#  'EX_udpgal_e',
#  'EX_23cump_e',
#  'MDH',
#  'NMNDA',
#  'RNDR1',
#  'HYD2pp',
#  'EX_gam_e',
#  'EX_malt_e',
#  'GLYCLTDx',
#  'ACALD',
#  'UMPK',
#  'EX_psclys_e',
#  'PYNP2r',
#  'MNt2pp',
#  'THRt4pp',
#  'EX_gam6p_e',
#  'EX_dmso_e',
#  'EX_udpglcur_e',
#  'SLNTtpp',
#  'RNTR2c',
#  'EX_asn__L_e',
#  'LALDO2x',
#  'PYK',
#  'PFL',
#  'RNDR2b',
#  'EX_LalaDgluMdap_e',
#  'GLYCTO3',
#  'EX_3cmp_e',
#  'CYStpp',
#  'EX_xylu__L_e',
#  'COBALT2tpp',
#  'DADK',
#  'Kt2pp',
#  'PPK2',
#  'EX_rib__D_e',
#  'EX_hxan_e',
#  'ATPS4rpp',
#  'EX_galct__D_e',
#  'EX_tartr__D_e',
#  'GF6PTA',
#  'CO2tpp',
#  'CYTDK2',
#  'EX_frulys_e',
#  'GND',
#  'EX_acmana_e',
#  'ARGDCpp',
#  'EX_manglyc_e',
#  'RNTR1c',
#  'EX_12ppd__S_e',
#  'EX_o2_e',
#  'EX_r5p_e',
#  'ACPPAT160',
#  'PUNP1',
#  'EX_xan_e',
#  'NI2t3pp',
#  'POR5',
#  'RNDR2',
#  'DASYN161',
#  'ASNS2',
#  'EX_gua_e',
#  'THD2pp',
#  'EX_gln__L_e',
#  'EX_alaala_e',
#  'EX_dcmp_e',
#  'PPCK',
#  'PGI',
#  'EX_acgam1p_e',
#  'LYSt2pp',
#  'ACtex',
#  'RPE',
#  'GLYK',
#  'PMPK',
#  'FORt2pp',
#  'EX_cgly_e',
#  'COBALT2t3pp',
#  'NADH18pp',
#  'GLNS',
#  'EX_cmp_e',
#  'NDPK2',
#  'EX_gthrd_e',
#  'FEROpp',
#  'ACPPAT161',
#  'CS',
#  'H2Otpp',
#  'ME2',
#  'ALAR',
#  'EX_h2o_e',
#  'NMNAT',
#  'RNDR1b',
#  'EX_sbt__D_e',
#  'EX_sucr_e',
#  'FORtex',
#  'HYD3pp',
#  'FHL']

# %%
i2=0
inANDdecr_and_stable= list()

while i2< len(inANDdecr):  #this code separates reactions that may have flat points from reactions that always increase and decrease
    
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_anaerobic.csv'.format(inANDdecr[i2]))
    i=0
    l= list()
    
    while i < 201:
        inf= csvFile.iloc[i,  2]
        flt= float(csvFile.iloc[i,  2])
    
        if csvFile.iloc[i,  2] == flt:
            l.append(csvFile.iloc[i,  2])
        
        i= i+1

    csvFile2= pd.DataFrame (l, columns = ['Biomass'])
    csvFile2.Biomass = csvFile2.Biomass.round(2)
    
    i=0
    
    while i < len(csvFile2)-1:
        if csvFile2.iloc[i,  0] == csvFile2.iloc[i+1,  0] and inANDdecr[i2] not in inANDdecr_and_stable:
            inANDdecr_and_stable.append(inANDdecr[i2])
            
        i=i+1
        
    i2= i2+1

inANDdecr_and_stable
# Out:
# ['EX_no_e',
#  'EX_man_e',
#  'EX_glc__D_e',
#  'NTRIR2x',
#  'NO3R1bpp',
#  'EX_all__D_e',
#  'EX_galt_e',
#  'EX_ala__D_e',
#  'EX_cynt_e',
#  'FBA',
#  'EX_fru_e',
#  'EX_acmum_e',
#  'SUCCt2_2pp',
#  'EX_fe3dcit_e',
#  'EX_udpgal_e',
#  'EX_23cump_e',
#  'EX_gam_e',
#  'EX_malt_e',
#  'MNt2pp',
#  'SLNTtpp',
#  'PYK',
#  'EX_3cmp_e',
#  'ARGDCpp',
#  'EX_manglyc_e',
#  'EX_o2_e',
#  'EX_r5p_e',
#  'EX_gua_e',
#  'EX_alaala_e',
#  'FORt2pp',
#  'EX_cmp_e',
#  'EX_sucr_e',
#  'FHL']

# %%
set1= set(inANDdecr)
set2= set(inANDdecr_and_stable)
l_left= list(set1-set2)
l_left

i2=0
inANDdecr_only= list()

while i2< len(l_left):  #this code separates reactions that may have flat points from reactions that always increase and decrease
    
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_anaerobic.csv'.format(l_left[i2]))
    i=0
    l= list()
    
    while i < 201:
        inf= csvFile.iloc[i,  2]
        flt= float(csvFile.iloc[i,  2])
    
        if csvFile.iloc[i,  2] == flt:
            l.append(csvFile.iloc[i,  2])
        
        i= i+1

    csvFile2= pd.DataFrame (l, columns = ['Biomass'])
    csvFile2.Biomass = csvFile2.Biomass.round(2)
    
    i=0
        
    while i < len(csvFile2)-1:
        
        if csvFile2.iloc[i,  0] != csvFile2.iloc[i+1,  0] and l_left[i2] not in inANDdecr_only:
            inANDdecr_only.append(l_left[i2])
        
        i=i+1
        
    i2= i2+1

inANDdecr_only
# Out:
# ['TMPK',
#  'EX_for_e',
#  'CO2tex',
#  'ZN2tpp',
#  'RNTR2c2',
#  'NDPK4',
#  'TRE6PH',
#  'MN2tpp',
#  'HCO3E',
#  'EX_tmao_e',
#  'EX_no3_e',
#  'MALS',
#  'EX_no2_e',
#  'EX_23ccmp_e',
#  'EX_val__L_e',
#  'DTMPK',
#  'DURIK1',
#  'GLCt2pp',
#  'DGK1',
#  'FUM',
#  'NH4tex',
#  'EX_etoh_e',
#  'CD2t3pp',
#  'EX_uacgam_e',
#  'EX_23camp_e',
#  'NADK',
#  'ALAALAr',
#  'SFGTHi',
#  'GDPTPDP',
#  'EX_thrp_e',
#  'SUCASPtpp',
#  'GLUDy',
#  'DASYN160',
#  'EX_LalaDgluMdapDala_e',
#  'FLDR2',
#  'EX_arab__L_e',
#  'EX_xyl__D_e',
#  'FBP',
#  'EX_pser__L_e',
#  'GK1',
#  'EX_mnl_e',
#  'MACPD',
#  'EX_h_e',
#  'NTD2',
#  'ZN2t3pp',
#  'H2Otex',
#  'SUCMALtpp',
#  'SUCCt3pp',
#  'PPC',
#  'EX_udpacgal_e',
#  'EX_melib_e',
#  'EX_acnam_e',
#  'EX_anhgm_e',
#  'EX_23dappa_e',
#  'MALt2_2pp',
#  'GDPDPK',
#  'NADH17pp',
#  'ETOHtex',
#  'ETOHtrpp',
#  'ALCD2x',
#  'ASPTA',
#  'CAT',
#  'NDPK5',
#  'EX_nh4_e',
#  'PUNP3',
#  'EX_23cgmp_e',
#  'ARBt2rpp',
#  'RNTR4c2',
#  'ACCOAC',
#  'AKGDH',
#  'EX_ac_e',
#  'EX_ascb__L_e',
#  'FORtppi',
#  'GLYCTO4',
#  'EX_tartr__L_e',
#  'EX_acgam_e',
#  'EX_co2_e',
#  'EX_glcr_e',
#  'EX_gal_e',
#  'LDH_D',
#  'EX_udpg_e',
#  'EX_acac_e',
#  'FADRx',
#  'Htex',
#  'MCOATA',
#  'NDPK8',
#  'H2SO',
#  'PTRCt2pp',
#  'PPS',
#  'NH4tpp',
#  'FE2tpp',
#  'GLYCDx',
#  'EX_lyx__L_e',
#  'CU2tpp',
#  'CITL',
#  'NTD11',
#  'EX_alltn_e',
#  'FDH5pp',
#  'F6PA',
#  'NI2tpp',
#  'GDPMNH',
#  'PUNP5',
#  'RNTR1c2',
#  'XYLI2',
#  'MDH',
#  'NMNDA',
#  'RNDR1',
#  'HYD2pp',
#  'GLYCLTDx',
#  'ACALD',
#  'UMPK',
#  'EX_psclys_e',
#  'PYNP2r',
#  'THRt4pp',
#  'EX_gam6p_e',
#  'EX_dmso_e',
#  'EX_udpglcur_e',
#  'RNTR2c',
#  'EX_asn__L_e',
#  'LALDO2x',
#  'PFL',
#  'RNDR2b',
#  'EX_LalaDgluMdap_e',
#  'GLYCTO3',
#  'CYStpp',
#  'EX_xylu__L_e',
#  'COBALT2tpp',
#  'DADK',
#  'Kt2pp',
#  'PPK2',
#  'EX_rib__D_e',
#  'EX_hxan_e',
#  'ATPS4rpp',
#  'EX_galct__D_e',
#  'EX_tartr__D_e',
#  'GF6PTA',
#  'CO2tpp',
#  'CYTDK2',
#  'EX_frulys_e',
#  'GND',
#  'EX_acmana_e',
#  'RNTR1c',
#  'EX_12ppd__S_e',
#  'ACPPAT160',
#  'PUNP1',
#  'EX_xan_e',
#  'NI2t3pp',
#  'POR5',
#  'RNDR2',
#  'DASYN161',
#  'ASNS2',
#  'THD2pp',
#  'EX_gln__L_e',
#  'EX_dcmp_e',
#  'PPCK',
#  'PGI',
#  'EX_acgam1p_e',
#  'LYSt2pp',
#  'ACtex',
#  'RPE',
#  'GLYK',
#  'PMPK',
#  'EX_cgly_e',
#  'COBALT2t3pp',
#  'NADH18pp',
#  'GLNS',
#  'NDPK2',
#  'EX_gthrd_e',
#  'FEROpp',
#  'ACPPAT161',
#  'CS',
#  'H2Otpp',
#  'ME2',
#  'ALAR',
#  'EX_h2o_e',
#  'NMNAT',
#  'RNDR1b',
#  'EX_sbt__D_e',
#  'FORtex',
#  'HYD3pp']

# %%
d1= pd.DataFrame (one, columns = ['Reaction names'])
d2= pd.DataFrame (flat, columns = ['Reaction names'])
d3= pd.DataFrame (diff_saturatedFINAL, columns = ['Reaction names'])
d4= pd.DataFrame (Ushaped_reactions, columns = ['Reaction names'])
d5= pd.DataFrame (mon_decr_and_stable, columns = ['Reaction names'])
d6= pd.DataFrame (mon_decr_only, columns = ['Reaction names'])
d7= pd.DataFrame (mon_incr_and_stable, columns = ['Reaction names'])
d8= pd.DataFrame (mon_incr_only, columns = ['Reaction names'])
d9= pd.DataFrame (inANDdecr_and_stable, columns = ['Reaction names'])
d10= pd.DataFrame (inANDdecr_only, columns = ['Reaction names'])

D.to_csv("one feasible value reactions anaerobic.csv")
d1.to_csv("monotonically decreasing reactions anaerobic.csv")
d2.to_csv("flat anaerobic.csv")
d3.to_csv("diff_saturated anaerobic.csv")
d4.to_csv("Ushaped_reactions anaerobic.csv")
d5.to_csv("monotonically decreasing and stable reactions anaerobic.csv")
d6.to_csv("monotonically decreasing only reactions anaerobic.csv")
d7.to_csv("monotonically increasing and stable reactions anaerobic.csv")
d8.to_csv("monotonically increasing only reactions anaerobic.csv")
d9.to_csv("increasing and decreasing and stable reactions anaerobic.csv")
d10.to_csv("increasing and decreasing only reactions anaerobic.csv")

# %%
len(one)
# Out:
# 1698

# %%
diff_saturatedFINAL
# Out:
# ['ACOLIPAabctex',
#  'ALAALAD',
#  'ALAabcpp',
#  'ALDD2x',
#  'ASPabcpp',
#  'ATPM',
#  'CHLabcpp',
#  'CLIPAabctex',
#  'CBPS',
#  'CD2abcpp',
#  'COBALT2abcpp',
#  'COLIPAabctex',
#  'CRNDabcpp',
#  'CRNabcpp',
#  'CTBTabcpp',
#  'CYSabc2pp',
#  'ARBabcpp',
#  'ECA4COLIPAabctex',
#  'ENLIPAabctex',
#  'ARGabcpp',
#  'FE2abcpp',
#  'ASNabcpp',
#  'G3PD5',
#  'G3PD6',
#  'G3PD7',
#  'ASPO3',
#  'ASPO4',
#  'ASPO5',
#  'GLCabcpp',
#  'ASPT',
#  'GALabcpp',
#  'GLUabcpp',
#  'GLYBabcpp',
#  'GLYC3Pabcpp',
#  'IDOND2',
#  'HG2abcpp',
#  'ILEabcpp',
#  'HISabcpp',
#  'HPYRRy',
#  'LDH_D2',
#  'LEUabcpp',
#  'LIPAabctex',
#  'LYSabcpp',
#  'MDH2',
#  'MDH3',
#  'MG2uabcpp',
#  'NADH10',
#  'NADH5',
#  'NADH9',
#  'NADPHQR2',
#  'NADPHQR3',
#  'NADPHQR4',
#  'NADTRHD',
#  'NI2abcpp',
#  'NTP1',
#  'NTP10',
#  'NTP3',
#  'NTP5',
#  'NTPP1',
#  'NTPP2',
#  'NTPP3',
#  'NTPP4',
#  'NTPP5',
#  'NTPP6',
#  'NTPP7',
#  'NTPP8',
#  'ORNabcpp',
#  'PDH',
#  'PROabcpp',
#  'PTRCabcpp',
#  'SPODM',
#  'THRA2',
#  'THRabcpp',
#  'VALabcpp',
#  'XYLabcpp',
#  'ZN2abcpp',
#  'POX',
#  'PPA2',
#  'DARBabcpp',
#  'DURAD',
#  'PYRDC']
